# %%
import sys
import os

PROJECT_ROOT = r"C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system"
sys.path.insert(0, PROJECT_ROOT)

print("Project root added:", PROJECT_ROOT)
# Out:
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system

# %%
# logging/prediction_logger.py
import json
import datetime
import os

from datetime import datetime
from ml_db.mongo_client import prediction_logs_collection

def log_prediction(customer_id, model_version, features, prediction, prediction_percentage):
    record = {
        "customer_id": customer_id,
        "timestamp": datetime.utcnow().isoformat(),
        "model_version": model_version,
        "features": features,
        "prediction": prediction,
        "prediction_percentage": prediction_percentage
    }

    prediction_logs_collection.insert_one(record)
