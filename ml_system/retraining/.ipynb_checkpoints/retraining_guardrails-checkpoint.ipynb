# %%
#Cooldown check
#Minimum data check
#Abort reasons
from datetime import datetime
from typing import Dict
import sys
import os

PROJECT_ROOT = r"C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system"
sys.path.insert(0, PROJECT_ROOT)

print("Project root added:", PROJECT_ROOT)
# Out:
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system

# %%
from ml_db.mongo_client import model_registry_collection, temp_prediction_log_collection
from retraining.decision_utils import cooldown_decide, data_sufficiency_check, retraining_dataset, full_data_generator, final_split, preprocess_data
# Out:
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system

# %%
model_cursor = model_registry_collection.find().sort("timestamp", -1).limit(1)
model = list(model_cursor)
model[0]['trained_at']
# Out:
# '2026-01-05T06:05:38.568290'

# %%
cooldown = cooldown_decide(model[0]['trained_at'])

# %%
data_sufficient = data_sufficiency_check()
# Out:
# 11

# %%
import numpy as np
import pandas as pd
data, train, val, full_data = retraining_dataset()

X = full_data.drop(columns = ['churn'])
y = full_data['churn'].copy()
X_train, X_val, y_train, y_val = final_split(X, y)

# %%
print(preprocess_data(X_train, X_val, y_train, "2"))
# Out:
# trained successfully!
