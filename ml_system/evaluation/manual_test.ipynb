# %%
import sys
import os
import random
import datetime

PROJECT_ROOT = r"C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system"
sys.path.insert(0, PROJECT_ROOT)

print("Project root added:", PROJECT_ROOT)
from evaluation.metrics import compute_metrics

joined_data = [
    {"prediction": 1, "actual": 1},
    {"prediction": 0, "actual": 0},
    {"prediction": 1, "actual": 0},
    {"prediction": 0, "actual": 1},
]

metrics = compute_metrics(joined_data)
print(metrics)
# Out:
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system
# {'confusion_matrix': {'TP': 1, 'TN': 1, 'FP': 1, 'FN': 1}, 'accuracy': 0.5, 'precision': 0.5, 'recall': 0.5, 'total_samples': 4}
