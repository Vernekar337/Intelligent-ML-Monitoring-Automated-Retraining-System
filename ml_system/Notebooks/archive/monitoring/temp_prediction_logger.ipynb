# %%
import sys
import os

PROJECT_ROOT = r"C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system"
sys.path.insert(0, PROJECT_ROOT)

print("Project root added:", PROJECT_ROOT)
# Out:
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system

# %%
from ml_db.mongo_client import temp_prediction_log_collection
from ml_db.mongo_client import prediction_logs_collection

pred_logs_cursor = prediction_logs_collection.find()
pred_logs = list(pred_logs_cursor)
pred_logs
# Out:
# [{'_id': ObjectId('694fac434ff3c44f85fa4e16'),
#   'customer_id': 'C400',
#   'timestamp': '2025-12-27T09:52:03.621222',
#   'model_version': 'v1',
#   'features': {'tenure': 10,
#    'MonthlyCharges': 70.5,
#    'TotalCharges': 85.0,
#    'Contract': 'Month-to-month',
#    'PaymentMethod': 'Electronic check',
#    'InternetService': 'Fiber optic',
#    'num_support_tickets': 21},
#   'prediction': 1.0,
#   'prediction_percentage': [0.6696590185165405]},
#  {'_id': ObjectId('69520f6efd46dcdd9098dc9a'),
#   'customer_id': 'C401',
#   'timestamp': '2025-12-29T05:19:42.236005',
#   'model_version': 'v1',
#   'features': {'tenure': 3,
#    'MonthlyCharges': 89.5,
#    'TotalCharges': 268.5,
#    'Contract': 'Month-to-month',
#    'PaymentMethod': 'Electronic check',
#    'InternetService': 'Fiber optic',
#    'num_support_tickets': 9},
#   'prediction': 1.0,
#   'prediction_percentage': [0.7100282311439514]},
#  {'_id': ObjectId('69520f99fd46dcdd9098dc9b'),
#   'customer_id': 'C402',
# ...

# %%
import random
for i in pred_logs:
    rand_no = random.uniform(0, 1)
    if(i['prediction_percentage'][0] > rand_no):
        actual_label = 1
    else:
        actual_label = 0
    i["actual_label"] = actual_label
    temp_prediction_log_collection.insert_one(i)
