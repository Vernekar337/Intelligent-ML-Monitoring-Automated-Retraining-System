# %%
import sys
import os

PROJECT_ROOT = r"C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system"
sys.path.insert(0, PROJECT_ROOT)

print("Project root added:", PROJECT_ROOT)
# Out:
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system

# %%
from orchestrator import run_system_cycle

result = run_system_cycle(model_version="v1")
# Out:
# Project root added: C:\Users\Sahil.s.Vernekar\OneDrive\Documents\ML\Churn\ml_system

# %%
print(result)
# Out:
# {'feature_drift': {'error': 'Baseline feature statistics not found'}, 'prediction_drift': {'drift_type': 'prediction_drift', 'model_version': 'v1', 'window': {'type': 'count_based', 'size': 100}, 'metrics': {'probability_psi': np.float64(0.0), 'class_balance_delta': 0.0}, 'distributions': {'reference_probability_distribution': [0.5, 0.0, 0.0, 0.0, 0.0, 0.08333, 0.16667, 0.16667, 0.08333, 0.0], 'current_probability_distribution': [0.5, 0.0, 0.0, 0.0, 0.0, 0.08333, 0.16667, 0.16667, 0.08333, 0.0]}, 'status': 'no_drift', 'generated_at': '2026-01-14T06:32:43.203244', '_id': ObjectId('6967388bb79bd56a923a8c73')}, 'performance_drift': {'error': "run_performance_monitoring() got an unexpected keyword argument 'model_version'"}, 'health_report': {'model_version': 'v1', 'health_snapshot': {'feature_drift': 'no_drift', 'prediction_drift': 'major_drift', 'performance_drift': 'no_drift'}, 'overall_status': 'warning', 'actions': {'retraining_recommended': False, 'urgency': 'monitor', 'reason': 'prediction_drift_detected_without_performance_degradation'}, 'source_reports': {'feature_drift_report_id': ObjectId('6956091b7dcd5c4b2b6e0c50'), 'prediction_drift_report_id': ObjectId('69523d37c1fa268abb0d0ad8'), 'performance_drift_report_id': ObjectId('6953994e71aa82511e8572f0')}, 'generated_at': '2026-01-14T06:32:43.257933', '_id': ObjectId('6967388bb79bd56a923a8c74')}, 'retraining': {'decision': 'no_action', 'reason': 'prediction_drift_detected_without_performance_degradation', 'evaluated_at': '2026-01-14T06:32:43.287367'}}
